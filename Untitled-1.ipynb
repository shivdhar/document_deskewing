# %%
import os
os.getpid()
# Out:
# 11710

# %%
import sys
sys.executable
# Out:
# '/home/dev2/anaconda3/envs/image_alignment/bin/python3.9'

# %%
from pathlib import Path

import cv2 as cv
from IPython.display import Image

# %%
sample_img = Path('data/misaligned_images/misaligned_images/0e27f636242845138158f132878a3351.jpg')

# %%
img = cv.imread(str(sample_img))

# %%
Image(sample_img)

# %%
img.shape
# Out:
# (983, 994, 3)

# %%
cv.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipykernel_11710/1548248515.py in <module>
# ----> 1 cv.imshow(img)
#
# error: OpenCV(4.5.3) :-1: error: (-5:Bad argument) in function 'imshow'
# > Overload resolution failed:
# >  - imshow() missing required argument 'mat' (pos 2)
# >  - imshow() missing required argument 'mat' (pos 2)
# >  - imshow() missing required argument 'mat' (pos 2)

# %%
cv.__version__
# Out:
# '4.5.3'
